# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome(executable_path='/Users/HP/Desktop/folders/others/chromedriver/chromedriver.exe')
d=20

try:
    url=f"https://gre.magoosh.com/flashcards/vocabulary/decks"
    #url2=f'https://gre.magoosh.com/flashcards/vocabulary/common-words-{}'
    driver.get(url)

    xpath=f"/html/body/div/div/div[{d+1}]/div/a[2]"
    #/html/body/div/div/div[7]/div/a[2]

    driver.find_element_by_xpath(xpath).click()
           # /html/body/div/div/div/div[2]/div/div[1]/a[2]
    word='/html/body/div/div/div/div[1]/div/div[1]/a[1]/div/h1'
    #text1=driver.find_element_by_class_name('flashcard-word').text
    #print(f"i am text broo{text1}")

    z=0

    #print(text1)
    list1=[]
    while len(list1)<50:

       # for g in range(0,2):
            xpath2='/html/body/div/div/div/div[2]/div/div[1]/a[2]'
            temp_list=[]

            driver.find_element_by_class_name('flashcard').click()
            #print('jii')

            text1=driver.find_element_by_class_name('flashcard-word').text
            text2=driver.find_element_by_class_name('flashcard-text').text
            text3=driver.find_element_by_class_name('flashcard-example').text
            temp_list.append(text1)
            temp_list.append(text2)


            #temp_list.append(text3)
            if temp_list not in list1:
                list1.append(temp_list)


                z+=1
            idk='/html/body/div/div/div/div[1]/div/div[2]/a[1]'
               #  /html/body/div/div/div/div[1]/div/div[2]/a[1]


            driver.find_element_by_css_selector('body > div > div > div > div.flashcard-container.u-margin-V-m > div > div.back.card.flashcard-card > a.card-footer.card-footer-success.text-center').click()
           # print("hii")
            print(f"{z} {temp_list}")
            time.sleep(3)
    #m=[['hey','hey'],['hey','hey'],['fr','khgesrg']]
except Exception as e:
    print(e)

print('please modify and run other code')


    
#     #list1=[['hey','hey2'],['hey2','jdskyfgvbut'],['hey','hey2'],['hey2','jdskyfgvbut']]
#     l=len(list1)
#     if l%2!=0:
#         p=['FLASHCARD #####',d+1]
#         list1.append(p)
#     list2=[]
#     for i in range(0,l,2):
#         li=[]
#         li.append(list1[i][0])
#         li.append(list1[i][1])
#         li.append(list1[i+1][0])

#         li.append(list1[i+1][1])

#         list2.append(li)
#     l=len(list2)

#     doc = Document('magoosh.docx')
#     doc.tables
#     q=233

#     for i in range(0,l):
#         q+=1
#         doc.tables[0].cell(q, 0).text = list2[i][0]
#         doc.tables[0].cell(q, 1).text = list2[i][1]
#         doc.tables[0].cell(q, 2).text = list2[i][2]
#         doc.tables[0].cell(q, 3).text = list2[i][3]
#         doc.tables[0].add_row() #ADD ROW HERE
#         #print("h")
# #     doc.tables[0].cell(q+1, 0).text = list2[-1][0]
# #     doc.tables[0].cell(q+1, 1).text = list2[-1][1]
# #     doc.tables[0].cell(q+1, 2).text = f'FLASHCARD {d+1}'
# #     doc.tables[0].cell(q+1, 3).text = 'ADDED'
# #     doc.tables[0].add_row() #ADD ROW HERE
#     doc.save("magoosh.docx")
#     #print(list2)
#     print(f"added  {d+1}th flashcard")
# Out:
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".flashcard"}
#   (Session info: chrome=80.0.3987.149)
#
# please modify and run other code

# %%
from docx import Document
l=len(list1)
if l%2!=0:
    p=['FLASHCARD #####','{d+1}']
    list1.append(p)
list2=[]
for i in range(0,l,2):
    li=[]
    li.append(list1[i][0])
    li.append(list1[i][1])
    li.append(list1[i+1][0])

    li.append(list1[i+1][1])

    list2.append(li)
l=len(list2)

doc = Document('magoosh.docx')
doc.tables
q=503
for i in range(0,l):
    q+=1
    doc.tables[0].cell(q, 0).text = list2[i][0]
    doc.tables[0].cell(q, 1).text = list2[i][1]
    doc.tables[0].cell(q, 2).text = list2[i][2]
    doc.tables[0].cell(q, 3).text = list2[i][3]
    doc.tables[0].add_row() #ADD ROW HERE
    #print("h")
doc.tables[0].cell(q+1, 0).text = f'LINE: {q+1}'
doc.tables[0].cell(q+1, 1).text = 'FLASHCARD'
doc.tables[0].cell(q+1, 2).text = f'  {d+1}'
doc.tables[0].cell(q+1, 3).text = 'ADDED'
doc.tables[0].add_row() #ADD ROW HERE
doc.save("magoosh.docx")
#print(list2)
print(f"added  {d+1} th flashcard")
# Out:
# added  20 th flashcard

# %%
q+2
# Out:
# 503

# %%
list2
# Out:
# [['lascivious',
#   'adjective: lecherous; sexually perverted',
#   'truculent',
#   'adjective: having a fierce, savage nature'],
#  ['chary',
#   'adjective: cautious, suspiciously reluctant to do something',
#   'exegesis',
#   'noun: critical explanation or analysis, especially of a text'],
#  ['alacrity',
#   'noun: an eager willingness to do something',
#   'ponderous',
#   'adjective: weighed-down; moving slowly'],
#  ['defray',
#   'verb: to help pay the cost of, either in part or full',
#   'feckless',
#   'adjective: lazy and irresponsible'],
#  ['fractious',
#   'adjective: irritable and is likely to cause disruption',
#   'artless',
#   'adjective: without cunning or deceit'],
#  ['attenuate',
#   'verb: to weaken (in terms of intensity); to taper off/become thinner.',
#   'apogee',
#   'noun: the highest point'],
#  ['penurious',
#   'adjective: lacking money; poor',
#   'byzantine',
#   'adjective: intricate and complex'],
#  ['equivocate',
# ...

# %%
from docx import Document
l=len(list1)
if l%2!=0:
    p=['FLASHCARD #####',8]
    list1.append(p)
list2=[]
for i in range(0,l,2):
    li=[]
    li.append(list1[i][0])
    li.append(list1[i][1])
    li.append(list1[i+1][0])

    li.append(list1[i+1][1])

    list2.append(li)
l=len(list2)

doc = Document('magoosh.docx')
doc.tables
q=341

for i in range(0,l):
    q+=1
    doc.tables[0].cell(q, 0).text = list2[i][0]
    doc.tables[0].cell(q, 1).text = list2[i][1]
    doc.tables[0].cell(q, 2).text = list2[i][2]
    doc.tables[0].cell(q, 3).text = list2[i][3]
    doc.tables[0].add_row() #ADD ROW HERE
    #print("h")
doc.tables[0].cell(q+1, 0).text = f'LINE: {q+1}'
doc.tables[0].cell(q+1, 1).text = 'FLASHCARD'
doc.tables[0].cell(q+1, 2).text = f'  {d+1}'
doc.tables[0].cell(q+1, 3).text = 'ADDED'
doc.tables[0].add_row() #ADD ROW HERE
doc.save("magoosh.docx")
#print(list2)
print(f"added  {d+1} th flashcard")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-2572f333706d> in <module>()
#      26     doc.tables[0].cell(q, 1).text = list2[i][1]
#      27     doc.tables[0].cell(q, 2).text = list2[i][2]
# ---> 28     doc.tables[0].cell(q, 3).text = list2[i][3]
#      29     doc.tables[0].add_row() #ADD ROW HERE
#      30     #print("h")
#
# ~\Anaconda3\lib\site-packages\docx\table.py in text(self, text)
#     268         p = tc.add_p()
#     269         r = p.add_r()
# --> 270         r.text = text
#     271
#     272     @property
#
# ~\Anaconda3\lib\site-packages\docx\oxml\text\run.py in text(self, text)
#     102     def text(self, text):
#     103         self.clear_content()
# --> 104         _RunContentAppender.append_to_run_from_text(self, text)
#     105
#     106
#
# ~\Anaconda3\lib\site-packages\docx\oxml\text\run.py in append_to_run_from_text(cls, r, text)
# ...

# %%
list3=list1
list4=list2
